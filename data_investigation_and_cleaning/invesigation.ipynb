# %%
import pandas as pd
from pathlib import Path

# basePath = Path(__file__).resolve().parent[2]
basePath = Path.cwd().resolve().parent

df = pd.read_csv(basePath / "data/developer_ai_learning_raw.csv")
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ResponseId       49191 non-null  int64
#  1   Age              49191 non-null  str
#  2   YearsCode        43042 non-null  float64
#  3   DevType          43680 non-null  str
#  4   LearnCodeChoose  46858 non-null  str
#  5   LearnCode        33556 non-null  str
#  6   LearnCodeAI      45201 non-null  str
#  7   AILearnHow       28257 non-null  str
#  8   AISelect         33720 non-null  str
#  9   AIAcc            33297 non-null  str
#  10  AISent           33467 non-null  str
# dtypes: float64(1), int64(1), str(9)
# memory usage: 4.1 MB
# None

# %%
print(df.head(3))
# Out:
#    ResponseId              Age  YearsCode               DevType  \
# 0           1  25-34 years old       14.0     Developer, mobile
# 1           2  25-34 years old       10.0   Developer, back-end
# 2           3  35-44 years old       12.0  Developer, front-end
#
#                                      LearnCodeChoose  \
# 0  Yes, I am not new to coding but am learning ne...
# 1  Yes, I am not new to coding but am learning ne...
# 2  Yes, I am not new to coding but am learning ne...
#
#                                            LearnCode  \
# 0  Online Courses or Certification (includes all ...
# 1  Online Courses or Certification (includes all ...
# 2  Online Courses or Certification (includes all ...
#
#                                          LearnCodeAI  \
# 0  Yes, I learned how to use AI-enabled tools for...
# 1  Yes, I learned how to use AI-enabled tools for...
# 2  Yes, I learned how to use AI-enabled tools for...
#
# ...

# %%
print(df.shape)
print(df.duplicated().sum())
print(df.isna().sum())
# Out:
# (49191, 11)
# 0
# ResponseId             0
# Age                    0
# YearsCode           6149
# DevType             5511
# LearnCodeChoose     2333
# LearnCode          15635
# LearnCodeAI         3990
# AILearnHow         20934
# AISelect           15471
# AIAcc              15894
# AISent             15724
# dtype: int64

# %%
df["ResponseId"].nunique()
# Out:
# 49191

# %%
print(df["Age"].value_counts())
print("=====")
print(df["DevType"].value_counts())
print("=====")
# Out:
# Age
# 25-34 years old      16519
# 35-44 years old      13241
# 18-24 years old       9210
# 45-54 years old       6275
# 55-64 years old       2626
# 65 years or older      942
# Prefer not to say      378
# Name: count, dtype: int64
# =====
# DevType
# Developer, full-stack                            12351
# Developer, back-end                               6453
# Student                                           3008
# Architect, software or solutions                  2684
# Developer, front-end                              1974
# Developer, desktop or enterprise applications     1919
# Other (please specify):                           1825
# Developer, mobile                                 1391
# Developer, embedded applications or devices       1274
# Academic researcher                               1131
# Engineering manager                               1068
# DevOps engineer or professional                   1053
# Data engineer                                      770
# ...

# %%
# ";" in the content
print(df["LearnCode"].value_counts())
print("=====")
# Out:
# LearnCode
# Other online resources (e.g. standard search, forum, online community);Stack Overflow or Stack Exchange;Technical documentation (is generated for/by the tool or system)                                                                                                                                                                                                                                      632
# Other online resources (e.g. standard search, forum, online community);Technical documentation (is generated for/by the tool or system)                                                                                                                                                                                                                                                                       465
# ...

# %%
# print(df["LearnCodeAI"].value_counts())
# print("=====")
# print(df["AIAcc"].value_counts())
# print("=====")
# print(df["AILearnHow"].value_counts())
# print("=====")
# print(df["AISelect"].value_counts())
# print("=====")
# print(df["YearsCode"].value_counts())
# print("=====")
# Out:
# YearsCode
# 10.0    3108
# 15.0    2540
# 20.0    2497
# 5.0     2267
# 8.0     2113
#         ...
# 98.0       1
# 89.0       1
# 78.0       1
# 76.0       1
# 82.0       1
# Name: count, Length: 78, dtype: int64
# =====
